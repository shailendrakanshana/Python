# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[5,6,7],[2,9,8])
# Out:
# [<matplotlib.lines.Line2D at 0x1913237e160>,
#  <matplotlib.lines.Line2D at 0x1913237e190>]

# %%
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
plt.plot([1,2,3],[3,5,7])
plt.title("My data")
plt.xlabel("X")
plt.ylabel('Y')
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
x = [1,2,3,4]
y = [1,5,8,10]
x1 = [3,6,7,8]
y1 = [4,6,8,9]
plt.plot(x,y)
plt.plot(x1, y1)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.arange(0,10,0.1)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,7,0.01)
y = np.sin(x)
plt.title("CodeFreakPyClub")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(x,y)
plt.show()
